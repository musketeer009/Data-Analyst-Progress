# %% [markdown]
# **Integer**

# %%
print(int(12))
print(int(12.89))
#print(int('a'))
#print(int('A'))
#print(int('Amit'))
print(int('10'))
#print(int('10.00'))
#print(type(10.0))
#print(int('10.08'))
print(int(True))
print(int(False))
# Out:
# 12
# 12
# 10
# 1
# 0

# %% [markdown]
# **Float**

# %%
print(float(21))
print(float('21'))
print(float(21.45))
print(float('21.34'))
print(float(True))
print(float(False))
# Out:
# 21.0
# 21.0
# 21.45
# 21.34
# 1.0
# 0.0

# %% [markdown]
# **String**

# %%
print(str('Shubham'))
print(str(12))
print(str(12.56))
print(str(True))
print(str(False))
# Out:
# Shubham
# 12
# 12.56
# 12
# 12.56
# True
# False

# %% [markdown]
# **Boolean**

# %%
print(bool(12))
print(bool(12.56))
print(bool(0))
print(bool(0.0001))
print(bool(-12))
print(bool('Shubham'))
print(bool(' '))
print(bool(''))
# Out:
# True
# True
# False
# True
# True
# True
# True
# False

# %% [markdown]
# **Exception**

# %%
#print(int('10.34'))
print(int(float('10.34')))
# Out:
# 10
