# %% [markdown]
# 1 Loading Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 2 Downloading Dataset

# %%
# !git clone https://github.com/AshishJangra27/datasets
# Out:
# fatal: destination path 'datasets' already exists and is not an empty directory.

# %% [markdown]
# 3 Loading Dataset

# %%
df = pd.read_csv('/content/datasets/Airbnb/airbnb_v2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
# 3           3  49871422                        Sapanca Breathable Bungalow
# 4           4  51245886                                      Bungalov Ev 2
#
#   rating reviews    host_name      host_id                   address  \
# 0   4.71      64    Mehmetcan  357334205.0  Kartepe, Kocaeli, Turkey
# 1    New       0        Fatih  386223873.0      Kaş, Antalya, Turkey
# 2   4.85      68       Giorgi  409690853.0          Imereti, Georgia
# 3    5.0      13        Melih  401873242.0  Sapanca, Sakarya, Turkey
# 4    New       0  Arp Sapanca  414884116.0  Sapanca, Sakarya, Turkey
#
#                                  features  \
# 0    2 guests,2 bedrooms,1 bed,1 bathroom
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0        id                                              name  \
# 12800       12800  44697740           Brown Dome House No. 3, full of healing
# 12801       12801  29975283      Bubble Hotel Ubud with Bathtub under the Sky
# 12802       12802  32977697                                  Paradise Eco Hub
# 12803       12803   8006146    WisDOME - Mentigi Bay Village - Gilis - Lombok
# 12804       12804  40547903  Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]
#
#       rating reviews host_name      host_id  \
# 12800   4.94      16     Aidan  161552316.0
# 12801   4.67       6    Martha  118954227.0
# 12802   4.67       3     Silas  175214568.0
# 12803   4.86       7   Cempaka     718423.0
# 12804   4.85      13      Achy  246470880.0
#
#                                                  address  \
# 12800  Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 12801                                 Gianyar, Indonesia
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  49849504                                     Perla bungalov
# 1           1  50891766  Authentic Beach Architect Sheltered Villa with...
# 2           2  50699164                                  cottages sataplia
# 3           3  49871422                        Sapanca Breathable Bungalow
# 4           4  51245886                                      Bungalov Ev 2
# 5           5  48650769                      CasaMia White Suite Treehouse
# 6           6  50765985                                     Ladin Bungalow
# 7           7  40947216                                     Lavender House
# 8           8  34043569                                           Prince's
# 9           9  42075682                    The Cottage, Private Pool Villa
#
#   rating reviews    host_name      host_id  \
# 0   4.71      64    Mehmetcan  357334205.0
# 1    New       0        Fatih  386223873.0
# ...

# %%
df.tail(7)
# Out:
#        Unnamed: 0                  id  \
# 12798       12798            32750338
# 12799       12799  640474109823176234
# 12800       12800            44697740
# 12801       12801            29975283
# 12802       12802            32977697
# 12803       12803             8006146
# 12804       12804            40547903
#
#                                                    name rating reviews  \
# 12798                     Cute dome house in the nature   4.93      44
# 12799                           Holiday home, Plemmirio    New       0
# 12800           Brown Dome House No. 3, full of healing   4.94      16
# 12801      Bubble Hotel Ubud with Bathtub under the Sky   4.67       6
# 12802                                  Paradise Eco Hub   4.67       3
# 12803    WisDOME - Mentigi Bay Village - Gilis - Lombok   4.86       7
# 12804  Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]   4.85      13
#
#              host_name      host_id  \
# 12798          Cholong   90542732.0
# ...

# %% [markdown]
# 4 Describe only numeric columns

# %%
df.describe()
# Out:
#          Unnamed: 0            id       host_id         price     bathrooms  \
# count  12805.000000  1.280500e+04  1.280500e+04  1.280500e+04  12805.000000
# mean    6402.000000  7.525187e+16  1.638192e+08  1.769780e+04      1.874424
# std     3696.629433  2.007933e+17  1.413622e+08  4.569364e+04      2.091399
# min        0.000000  1.313100e+04  2.303900e+04  3.930000e+02      0.000000
# 25%     3201.000000  2.023958e+07  3.700032e+07  3.994000e+03      1.000000
# 50%     6402.000000  3.682229e+07  1.256459e+08  8.175000e+03      1.000000
# 75%     9603.000000  4.999760e+07  2.639623e+08  1.606200e+04      2.000000
# max    12804.000000  7.017905e+17  4.758973e+08  1.907963e+06     50.000000
#
#                beds        guests        toiles      bedrooms       studios
# count  12805.000000  12805.000000  12805.000000  12805.000000  12805.000000
# mean       3.316751      5.213745      0.019211      2.136041      0.023585
# ...

# %% [markdown]
# 5 Shows basic info & str of all columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12805 entries, 0 to 12804
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    12805 non-null  int64
#  1   id            12805 non-null  int64
#  2   name          12805 non-null  object
#  3   rating        12805 non-null  object
#  4   reviews       12805 non-null  object
#  5   host_name     12797 non-null  object
#  6   host_id       12805 non-null  float64
#  7   address       12805 non-null  object
#  8   features      12805 non-null  object
#  9   amenities     12805 non-null  object
#  10  safety_rules  12805 non-null  object
#  11  hourse_rules  12805 non-null  object
#  12  img_links     12805 non-null  object
#  13  price         12805 non-null  int64
#  14  country       12805 non-null  object
#  15  bathrooms     12805 non-null  int64
#  16  beds          12805 non-null  int64
#  17  guests        12805 non-null  int64
# ...

# %% [markdown]
# 6 true if null but not understandable

# %%
df.isnull()
# Out:
#        Unnamed: 0     id   name  rating  reviews  host_name  host_id  address  \
# 0           False  False  False   False    False      False    False    False
# 1           False  False  False   False    False      False    False    False
# 2           False  False  False   False    False      False    False    False
# 3           False  False  False   False    False      False    False    False
# 4           False  False  False   False    False      False    False    False
# ...           ...    ...    ...     ...      ...        ...      ...      ...
# 12800       False  False  False   False    False      False    False    False
# 12801       False  False  False   False    False      False    False    False
# 12802       False  False  False   False    False      False    False    False
# 12803       False  False  False   False    False      False    False    False
# 12804       False  False  False   False    False      False    False    False
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# id                 0
# name               0
# rating             0
# reviews            0
# host_name          8
# host_id            0
# address            0
# features           0
# amenities          0
# safety_rules       0
# hourse_rules       0
# img_links          0
# price              0
# country            0
# bathrooms          0
# beds               0
# guests             0
# toiles             0
# bedrooms           0
# studios            0
# checkin          800
# checkout        2450
# dtype: int64

# %% [markdown]
# 8 Drop all rows if any value is null

# %%
df.dropna()
# Out:
#        Unnamed: 0                  id  \
# 0               0            49849504
# 1               1            50891766
# 2               2            50699164
# 3               3            49871422
# 4               4            51245886
# ...           ...                 ...
# 12799       12799  640474109823176234
# 12800       12800            44697740
# 12801       12801            29975283
# 12803       12803             8006146
# 12804       12804            40547903
#
#                                                     name rating reviews  \
# 0                                         Perla bungalov   4.71      64
# 1      Authentic Beach Architect Sheltered Villa with...    New       0
# 2                                      cottages sataplia   4.85      68
# 3                            Sapanca Breathable Bungalow    5.0      13
# 4                                          Bungalov Ev 2    New       0
# ...

# %% [markdown]
# Value are not saved yet

# %%
df
# Out:
#        Unnamed: 0        id  \
# 0               0  49849504
# 1               1  50891766
# 2               2  50699164
# 3               3  49871422
# 4               4  51245886
# ...           ...       ...
# 12800       12800  44697740
# 12801       12801  29975283
# 12802       12802  32977697
# 12803       12803   8006146
# 12804       12804  40547903
#
#                                                     name rating reviews  \
# 0                                         Perla bungalov   4.71      64
# 1      Authentic Beach Architect Sheltered Villa with...    New       0
# 2                                      cottages sataplia   4.85      68
# 3                            Sapanca Breathable Bungalow    5.0      13
# 4                                          Bungalov Ev 2    New       0
# ...                                                  ...    ...     ...
# 12800            Brown Dome House No. 3, full of healing   4.94      16
# ...

# %% [markdown]
# 9 Drop rows if value is null from any specific column

# %%
df.dropna(subset = 'host_name')
# Out:
#        Unnamed: 0        id  \
# 0               0  49849504
# 1               1  50891766
# 2               2  50699164
# 3               3  49871422
# 4               4  51245886
# ...           ...       ...
# 12800       12800  44697740
# 12801       12801  29975283
# 12802       12802  32977697
# 12803       12803   8006146
# 12804       12804  40547903
#
#                                                     name rating reviews  \
# 0                                         Perla bungalov   4.71      64
# 1      Authentic Beach Architect Sheltered Villa with...    New       0
# 2                                      cottages sataplia   4.85      68
# 3                            Sapanca Breathable Bungalow    5.0      13
# 4                                          Bungalov Ev 2    New       0
# ...                                                  ...    ...     ...
# 12800            Brown Dome House No. 3, full of healing   4.94      16
# ...

# %%
len(df)
# Out:
# 12805

# %% [markdown]
# 10 to remove null values from dataset we shoud asiign or replace by new dataset

# %%
df =df.dropna(subset = 'host_name')

# %%
len(df)
# Out:
# 12797

# %%
df= df.dropna()

# %%
len(df)
# Out:
# 10189

# %% [markdown]
# # Updating null value
# ### Load data again

# %%
df= pd.read_csv('/content/datasets/Airbnb/airbnb_v2.csv')

# %%
df['host_name'].isnull().sum()
# Out:
# np.int64(8)

# %%
df = df['host_name'].fillna('Unknown').isnull().sum()
# here now df containg an integer value df is no dataframe now

# %%
df.describe()
# therefore this command will not work

# %%
df['id']
# Out:
# 0        49849504
# 1        50891766
# 2        50699164
# 3        49871422
# 4        51245886
#            ...
# 12800    44697740
# 12801    29975283
# 12802    32977697
# 12803     8006146
# 12804    40547903
# Name: id, Length: 12805, dtype: int64

# %%
df['host_name']= df['host_name'].fillna('unknown')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12805 entries, 0 to 12804
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    12805 non-null  int64
#  1   id            12805 non-null  int64
#  2   name          12805 non-null  object
#  3   rating        12805 non-null  object
#  4   reviews       12805 non-null  object
#  5   host_name     12805 non-null  object
#  6   host_id       12805 non-null  float64
#  7   address       12805 non-null  object
#  8   features      12805 non-null  object
#  9   amenities     12805 non-null  object
#  10  safety_rules  12805 non-null  object
#  11  hourse_rules  12805 non-null  object
#  12  img_links     12805 non-null  object
#  13  price         12805 non-null  int64
#  14  country       12805 non-null  object
#  15  bathrooms     12805 non-null  int64
#  16  beds          12805 non-null  int64
#  17  guests        12805 non-null  int64
# ...

# %% [markdown]
# not removed only updated

# %%
len(df)
# Out:
# 12805

# %% [markdown]
# ###duplicates handeling

# %%
len(df['id'])
# Out:
# 12805

# %% [markdown]
# ##Convert list to array

# %%
df['id'].values
# Out:
# array([49849504, 50891766, 50699164, ..., 32977697,  8006146, 40547903])

# %% [markdown]
# ##Unique values

# %%
df['id'].unique()
# Out:
# array([49849504, 50891766, 50699164, ..., 32977697,  8006146, 40547903])

# %% [markdown]
# ## Count the uniques

# %%
df['id'].nunique()
# Out:
# 12805

# %% [markdown]
# ###Deleting columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'rating', 'reviews', 'host_name', 'host_id',
#        'address', 'features', 'amenities', 'safety_rules', 'hourse_rules',
#        'img_links', 'price', 'country', 'bathrooms', 'beds', 'guests',
#        'toiles', 'bedrooms', 'studios', 'checkin', 'checkout'],
#       dtype='object')

# %%
del df['Unnamed: 0']

# %% [markdown]
# ### Cleaning columns

# %%
df['id']
# Out:
# 0        49849504
# 1        50891766
# 2        50699164
# 3        49871422
# 4        51245886
#            ...
# 12800    44697740
# 12801    29975283
# 12802    32977697
# 12803     8006146
# 12804    40547903
# Name: id, Length: 12805, dtype: int64

# %%
df['name'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##Counting the values

# %%
df['name'].value_counts()  #return sum of unique element
# Out:
# name
# Dorm Bed in Traditional Ger - Mongol Ujin Camp                               6
# Haveli  - Large room in Art & Book filled mansion!                           5
# The goat village Nagtibba By Bakri Chhap                                     4
# InnerX-Stay, Floating Homestay in Lan Ha bay                                 4
# Comfort room with breakfast included                                         3
#                                                                             ..
# Lalie Guest House - Complete House                                           1
# ✿Surfer's Dream✿                                                             1
# Stunning modern 3 bedroom apartment in Netanya with spectacular sea views    1
# Green Garden                                                                 1
# Charming & comfortable bungalow                                              1
# Name: count, Length: 12716, dtype: int64

# %%
df['rating'].unique()
# Out:
# array(['4.71', 'New', '4.85', '5.0', '4.67', '4.97', '4.89', '4.83',
#        '4.87', '4.9', '4.75', '4.76', '4.84', '4.79', '4.82', '4.93',
#        '4.96', '4.6', '4.64', '4.68', '4.8', '4.69', '4.58', '4.63',
#        '4.91', '4.88', '4.94', '4.92', '4.86', '4.78', '4.57', '4.99',
#        '4.98', '4.74', '4.7', '4.77', '4.72', '4.73', '4.95', '4.81',
#        '4.53', '4.59', '4.62', '4.61', '4.51', '4.54', '4.56', '4.65',
#        '4.55', '4.66', '4.52', '4.5', '4.33', '4.26', '3.33', '4.2',
#        '4.0', '4.48', '4.38', '3.0', '4.49', '4.28', '4.45', '4.25',
#        '4.36', '4.46', '4.44', '4.43', '3.75', '3.25', '4.13', '4.15',
#        '3.88', '4.29', '4.4', '3.5', '4.31'], dtype=object)

# %%
df[df['rating']=='New']
# Out:
#                        id                                               name  \
# 1                50891766  Authentic Beach Architect Sheltered Villa with...
# 4                51245886                                      Bungalov Ev 2
# 5                48650769                      CasaMia White Suite Treehouse
# 6                50765985                                     Ladin Bungalow
# 7                40947216                                     Lavender House
# ...                   ...                                                ...
# 12790            53925646  Dome2 Rooms Dome2 in a home where you can esca...
# 12791            41257160    Romantic stay at Tent galaxy villa with jacuzzi
# 12793  621201623913222432        Kintamani Glamping Black Lava camp Potato 2
# 12795            44045739                                       Tambu a mare
# 12799  640474109823176234                            Holiday home, Plemmirio
#
# ...

# %%
df[df['rating'] !='New']
# Out:
#              id                                               name rating  \
# 0      49849504                                     Perla bungalov   4.71
# 2      50699164                                  cottages sataplia   4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.0
# 9      42075682                    The Cottage, Private Pool Villa   4.67
# 10     50425621  A private pension hut on the hillside of Sokli...   4.97
# ...         ...                                                ...    ...
# 12800  44697740            Brown Dome House No. 3, full of healing   4.94
# 12801  29975283       Bubble Hotel Ubud with Bathtub under the Sky   4.67
# 12802  32977697                                   Paradise Eco Hub   4.67
# 12803   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok   4.86
# 12804  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]   4.85
#
#       reviews  host_name      host_id  \
# 0          64  Mehmetcan  357334205.0
# ...

# %%
df[df['rating'] !='New']['rating'].astype('float').mean()
# Out:
# np.float64(4.857475195517684)

# %% [markdown]
# ##Replace

# %%
df['rating'] = df['rating'].replace('New',0)
df['rating'].replace('New',0, inplace = True)
# Out:
# <ipython-input-211-da57feeb91f1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].replace('New',0, inplace = True)

# %% [markdown]
# # Decrease the mean

# %%
df['rating'].astype("float").mean()
# Out:
# np.float64(3.249823506442796)

# %%
df.columns
# Out:
# Index(['id', 'name', 'rating', 'reviews', 'host_name', 'host_id', 'address',
#        'features', 'amenities', 'safety_rules', 'hourse_rules', 'img_links',
#        'price', 'country', 'bathrooms', 'beds', 'guests', 'toiles', 'bedrooms',
#        'studios', 'checkin', 'checkout'],
#       dtype='object')

# %%
df['reviews'].unique()
# Out:
# array(['64', '0', '68', '13', '3', '77', '55', '116', '23', '21', '8',
#        '52', '17', '61', '49', '38', '4', '15', '26', '5', '2', '85', '9',
#        '20', '11', '7', '1', '241', '41', '10', '25', '154', '44', '19',
#        '58', '137', '33', '12', '18', '16', '113', '125', '42', '244',
#        '27', '188', '34', '69', '97', '6', '86', '114', '65', '91', '32',
#        '53', '231', '99', '14', '120', '29', '28', '22', '123', '90',
#        '124', '110', '79', '93', '54', '59', '74', '31', '48', '30', '89',
#        '92', '35', '24', '229', '40', '102', '39', '194', '100', '147',
#        '37', '78', '88', '71', '130', '576', '1,003', '261', '726', '127',
#        '76', '84', '36', '60', '192', '46', '135', '62', '159', '158',
#        '45', '95', '104', '211', '43', '121', '109', '210', '107', '98',
#        '310', '96', '73', '50', '82', '66', '943', '254', '571', '72',
#        '51', '246', '136', '165', '67', '807', '262', '548', '266', '181',
# ...

# %% [markdown]
# ## here it detect "1,003"

# %%
df['reviews']= df['reviews'].astype("int")

# %%
df['reviews']= df['reviews'].str.replace(',', '').astype('int')
#.str itself does not convert values
#to strings. It’s just a string accessor that lets you apply string methods to each element of a pandas Series if those elements are already strings

# %%
df['reviews']
# Out:
# 0        64
# 1         0
# 2        68
# 3        13
# 4         0
#          ..
# 12800    16
# 12801     6
# 12802     3
# 12803     7
# 12804    13
# Name: reviews, Length: 12805, dtype: object

# %%
df['reviews'].mean()

# %%
df['reviews'].sum()
# Out:
# np.int64(462773)

# %%
df['host_name'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['host_name']= df['host_name'].fillna('unknown')

# %%
df['host_id'].value_counts()
# Out:
# host_id
# 157378426.0    28
# 262573392.0    13
# 45788344.0     13
# 156292477.0    13
# 95903847.0     12
#                ..
# 385223440.0     1
# 90542732.0      1
# 281370526.0     1
# 430105736.0     1
# 441844482.0     1
# Name: count, Length: 10375, dtype: int64

# %%
df[df['host_id']== 157378426.0]
# Out:
#                        id                                               name  \
# 1190   601816645157829673                                      Stone Cottage
# 1544   628897626500350545               Blissful cottage in the woods| Tandi
# 1557             45644216      Beautiful Sunny Cottage|250 meter Trek| Jibhi
# 1561   636631343388002719        Entire cottage with a room & attic in Tandi
# 1571   614293947503916670           Wooden hut with the Valley view in jibhi
# 1614   616569469785545211                 Peaceful Haven in an Apple Orchard
# 3080             52505611                      A Mudhouse In A Resort| Chhet
# 3142             52162851     Vibrant Room In A Beautiful Cottage| Hatu Peak
# 5276   578733555164036351      Magnificent Treehouse with Valley View| Tandi
# 5284   669002665572906395                      Picturesque Treehouse | Tandi
# 5311   635983225003873129           Cute Rural Getaway Chakrata| Cottage2 R1
# ...

# %% [markdown]
# ##Address

# %%
df['address']
# Out:
# 0                                 Kartepe, Kocaeli, Turkey
# 1                                     Kaş, Antalya, Turkey
# 2                                         Imereti, Georgia
# 3                                 Sapanca, Sakarya, Turkey
# 4                                 Sapanca, Sakarya, Turkey
#                                ...
# 12800    Imhoe-myeon, Jindo, South Jeolla Province, Sou...
# 12801                                   Gianyar, Indonesia
# 12802                                       Kabale, Uganda
# 12803          Gunung Sari, Nusa Tenggara Barat, Indonesia
# 12804                                Uruma, Okinawa, Japan
# Name: address, Length: 12805, dtype: object

# %%
df['address'].str.split(',')  # is dataframe m jo values h use single by single uthaega or split krega
# Out:
# 0                             [Kartepe,  Kocaeli,  Turkey]
# 1                                 [Kaş,  Antalya,  Turkey]
# 2                                      [Imereti,  Georgia]
# 3                             [Sapanca,  Sakarya,  Turkey]
# 4                             [Sapanca,  Sakarya,  Turkey]
#                                ...
# 12800    [Imhoe-myeon,  Jindo,  South Jeolla Province, ...
# 12801                                [Gianyar,  Indonesia]
# 12802                                    [Kabale,  Uganda]
# 12803      [Gunung Sari,  Nusa Tenggara Barat,  Indonesia]
# 12804                            [Uruma,  Okinawa,  Japan]
# Name: address, Length: 12805, dtype: object

# %%
df['address'].str.split(',').str[-1].str.strip().unique()
# Out:
# array(['Turkey', 'Georgia', 'Vietnam', 'Thailand', 'South Korea', 'India',
#        'Philippines', 'Japan', 'Lebanon', 'Taiwan', 'Israel', 'Armenia',
#        'Cyprus', 'Lithuania', 'Slovakia', 'Denmark', 'Germany',
#        'Indonesia', 'Poland', 'Romania', 'Greece', 'Ukraine', 'Hungary',
#        'Albania', 'Bulgaria', 'Malaysia', 'Montenegro', 'Slovenia',
#        'Czechia', 'Sweden', 'Austria', 'Croatia', 'Tanzania', 'Italy',
#        'Sri Lanka', 'Bosnia & Herzegovina', 'Kenya', 'Serbia',
#        'Seychelles', 'Finland', 'Norway', 'Iceland', 'Greenland',
#        'United States', 'Canada', 'Svalbard & Jan Mayen', 'France',
#        'Australia', 'Morocco', 'Egypt', 'South Africa', 'Spain',
#        'United Arab Emirates', 'United Kingdom', 'Pakistan', 'Nepal',
#        'Singapore', 'Cambodia', 'Azerbaijan', 'Estonia', 'Latvia',
#        'Costa Rica', 'Netherlands', 'Portugal', 'New Zealand', 'Panama',
#        'Mexico', 'Peru', 'Chile', 'Belize', 'Colombia', 'Switzerland',
# ...

# %%
df['country_name']=df['address'].str.split(',').str[-1].str.strip()

# %%
df
# Out:
#              id                                               name rating  \
# 0      49849504                                     Perla bungalov   4.71
# 1      50891766  Authentic Beach Architect Sheltered Villa with...      0
# 2      50699164                                  cottages sataplia   4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.0
# 4      51245886                                      Bungalov Ev 2      0
# ...         ...                                                ...    ...
# 12800  44697740            Brown Dome House No. 3, full of healing   4.94
# 12801  29975283       Bubble Hotel Ubud with Bathtub under the Sky   4.67
# 12802  32977697                                   Paradise Eco Hub   4.67
# 12803   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok   4.86
# 12804  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]   4.85
#
#       reviews    host_name      host_id  \
# ...

# %%
df[df['address'].str.split(',').str.len()==4]
# Out:
#                        id                                               name  \
# 10               50425621  A private pension hut on the hillside of Sokli...
# 39               21082489                               LOGIN OKINAWA -wood-
# 51     679805160588663838                             LOGIN OKINAWA -plants-
# 54               34029409                  恩纳村的打卡圣地网红海景小木屋Cinderella J House
# 84               49576819  Star-studded rooms with activities in front of...
# ...                   ...                                                ...
# 12790            53925646  Dome2 Rooms Dome2 in a home where you can esca...
# 12792  582235702055745984  Private design house in the form of a dome in ...
# 12794            47754537  Sensible Jeju Seongsan Private House, Dongri N...
# 12798            32750338                      Cute dome house in the nature
# 12800            44697740            Brown Dome House No. 3, full of healing
#
# ...

# %% [markdown]
# ##Features

# %%
df['features'].str.split(',').str.len().unique()
# Out:
# array([4, 3, 2, 1])

# %%
df
# Out:
#              id                                               name rating  \
# 0      49849504                                     Perla bungalov   4.71
# 1      50891766  Authentic Beach Architect Sheltered Villa with...      0
# 2      50699164                                  cottages sataplia   4.85
# 3      49871422                        Sapanca Breathable Bungalow    5.0
# 4      51245886                                      Bungalov Ev 2      0
# ...         ...                                                ...    ...
# 12800  44697740            Brown Dome House No. 3, full of healing   4.94
# 12801  29975283       Bubble Hotel Ubud with Bathtub under the Sky   4.67
# 12802  32977697                                   Paradise Eco Hub   4.67
# 12803   8006146     WisDOME - Mentigi Bay Village - Gilis - Lombok   4.86
# 12804  40547903   Enjoy Vitamin SEA!  Ocean Front! [Ocean's Seven]   4.85
#
#       reviews    host_name      host_id  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'rating', 'reviews', 'host_name', 'host_id', 'address',
#        'features', 'amenities', 'safety_rules', 'hourse_rules', 'img_links',
#        'price', 'country', 'bathrooms', 'beds', 'guests', 'toiles', 'bedrooms',
#        'studios', 'checkin', 'checkout', 'country_name'],
#       dtype='object')

# %%
country = 'India'
print(int(df[df['country_name'] == country]['price'].mean()))
print(int(df[df['country_name'] == country]['price'].min()))
print(int(df[df['country_name'] == country]['price'].max()))
# Out:
# 7536
# 393
# 182588
